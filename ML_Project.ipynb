# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("train.csv")
df
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             3424175        0       11053717           49.00         W
# 1             3206179        0        5150800           57.95         W
# 2             3410455        0       10713596          115.95         W
# 3             3058578        0        1611950          100.00         H
# 4             3242131        0        6111087           95.00         W
# ...               ...      ...            ...             ...       ...
# 442900        3020019        0         832530           29.00         W
# 442901        3546388        0       14827575           97.00         W
# 442902        3087445        0        2036666          100.00         R
# 442903        3066953        0        1724427           25.00         H
# 442904        3505849        0       13621776           50.00         S
#
#         card1  card2  card3             card4  card5  ...  \
# ...

# %%
df.isna().sum()
# Out:
# TransactionID          0
# isFraud                0
# TransactionDT          0
# TransactionAmt         0
# ProductCD              0
#                    ...
# id_36             337369
# id_37             337369
# id_38             337369
# DeviceType        337504
# DeviceInfo        353982
# Length: 434, dtype: int64

# %%
df.describe()
# Out:
#        TransactionID        isFraud  TransactionDT  TransactionAmt  \
# count   4.429050e+05  442905.000000   4.429050e+05   442905.000000
# mean    3.282059e+06       0.034989   7.366857e+06      135.273690
# std     1.705119e+05       0.183753   4.617568e+06      232.955213
# min     2.987002e+06       0.000000   8.646900e+04        0.251000
# 25%     3.134224e+06       0.000000   3.021834e+06       43.744000
# 50%     3.282155e+06       0.000000   7.301614e+06       68.950000
# 75%     3.429574e+06       0.000000   1.123641e+07      125.000000
# max     3.577539e+06       1.000000   1.581113e+07     6085.230000
#
#                card1          card2          card3          card5  \
# count  442905.000000  436201.000000  441724.000000  439730.000000
# mean     9901.266082     362.542367     153.188550     199.276736
# std      4901.960786     157.784513      11.314301      41.232396
# min      1001.000000     100.000000     100.000000     100.000000
# ...

# %%
df.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        3424175        0       11053717           49.00         W   5033
# 1        3206179        0        5150800           57.95         W   4527
# 2        3410455        0       10713596          115.95         W   2772
# 3        3058578        0        1611950          100.00         H  14290
# 4        3242131        0        6111087           95.00         W  12839
#
#    card2  card3       card4  card5  ...        id_31  id_32      id_33  \
# 0  269.0  150.0  mastercard  224.0  ...          NaN    NaN        NaN
# 1  376.0  150.0        visa  226.0  ...          NaN    NaN        NaN
# 2  512.0  150.0        visa  226.0  ...          NaN    NaN        NaN
# 3  512.0  150.0        visa  226.0  ...  chrome 62.0   24.0  1920x1080
# 4  321.0  150.0        visa  226.0  ...          NaN    NaN        NaN
#
#             id_34  id_35 id_36 id_37  id_38  DeviceType  DeviceInfo
# ...

# %% [markdown]
# # ## Exploratory Data Analysis(EDA)

# %%
count_classes = pd.value_counts(df['isFraud'])
count_classes.plot(kind = 'bar',rot=0)
plt.title("Fraud class histogram")
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
bx = df.plot.scatter(x='TransactionAmt', y='isFraud', color='Blue', label='Fraud')
print("Checking the amount for which fraud transaction occured")
plt.show()
# Out:
# Checking the amount for which fraud transaction occured

# %%
x=df[['TransactionDT','ProductCD','TransactionAmt','card1','card2','isFraud']]

# %%
x
# Out:
#         TransactionDT ProductCD  TransactionAmt  card1  card2  isFraud
# 0            11053717         W           49.00   5033  269.0        0
# 1             5150800         W           57.95   4527  376.0        0
# 2            10713596         W          115.95   2772  512.0        0
# 3             1611950         H          100.00  14290  512.0        0
# 4             6111087         W           95.00  12839  321.0        0
# ...               ...       ...             ...    ...    ...      ...
# 442900         832530         W           29.00   3277  111.0        0
# 442901       14827575         W           97.00  18132  567.0        0
# 442902        2036666         R          100.00   6019  583.0        0
# 442903        1724427         H           25.00  10737  399.0        0
# 442904       13621776         S           50.00   6019  583.0        0
#
# [442905 rows x 6 columns]

# %%
import seaborn as sns
plt.figure(figsize=(12, 12))
sns.heatmap(x.corr(),annot=True,linewidths=1)
# Out:
# <AxesSubplot:>
